# %%
from __future__ import print_function, division

# %matplotlib inline

import numpy as np

import nsfg
import first
import thinkstats2
import thinkplot

#Import the data (used the example from chap04ex)
live, firsts, others = first.MakeFrames()

#Calculate first weight
first_wgt = firsts.totalwgt_lb
first_wgt_dropna = first_wgt.dropna()
print('Firsts', len(first_wgt), len(first_wgt_dropna))

#Calculate other weight
other_wgt = others.totalwgt_lb
other_wgt_dropna = other_wgt.dropna()
print('Others', len(other_wgt), len(other_wgt_dropna))

first_pmf = thinkstats2.Pmf(first_wgt_dropna, label='first')
other_pmf = thinkstats2.Pmf(other_wgt_dropna, label='other')

#4-1 Checking my weight against first_weight group as I was first born
def PercentileRank():
    count = 0
    your_wgt = 8.9
    for wgt in first_wgt:
        if wgt <= your_wgt:
            count += 1

    percentile_rank = 100.0 * count / len(first_wgt)
    return percentile_rank

PercentileRank()
#Sent a text to my mom and apologized since I was in 90th percentile

#4-2 Generate 1000 numbers from random.random
from random import random
myRandos = []
for _ in range(100):
    myRandos.append(random())
print(myRandos)

#4-2 Plotting CDF  from random.random
cdf = thinkstats2.Cdf(myRandos, label = 'CDF of Random numbers to 1000')
thinkplot.Cdf(cdf)
thinkplot.Show(xlabel = 'Numbers to 1000' , ylabel = 'CDF')

#4-2 Plotting PMF from random.random
pmf = thinkstats2.Pmf(myRandos, label = 'PMF of Random numbers to 1000')
thinkplot.Pmf(pmf)
thinkplot.Show(xlabel = 'Numbers to 1000', ylabel = 'PMF')
# Out:
# Firsts 4413 4363
# Others 4735 4675
# ...
