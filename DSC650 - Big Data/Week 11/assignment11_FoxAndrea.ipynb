# %% [markdown]
# ```
# Name: Andrea Fox
# Date: May 29, 2021
# Course: DSC650 - T301 Big Data
# Assignment: Assignment 11
# ```

# %% [markdown]
# ## Assignment 11
# ```
# Using section 8.1 in Deep Learning with Python as a guide, implement an LSTM text generator. Train the model on the Enron corpus or a text source of your choice. Save the model and generate 20 examples to the results directory of dsc650/assignments/assignment11/.
# ```

# %%
#load libraries
import os
from pathlib import Path
import keras
import numpy as np
import tensorflow as tf
from keras import layers
import random
import sys

# %%
#set directories and create results folder
current_dir = Path(os.getcwd()).absolute()
results_dir = current_dir.joinpath('results')
results_dir.mkdir(parents=True, exist_ok=True)

# %%
#load in data. Used gutenberg.org and Pride and Prejudice as my text https://gutenberg.org/files/1342/1342-0.txt
path = keras.utils.get_file(
    '1342-0.txt',
    origin='https://gutenberg.org/files/1342')
text = open(path, encoding = 'utf-8').read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 1809

# %%
#extract partially-overlapping sequences of length maxlen, one-hot encode them and pack them in a 3D numpy array
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 583
# Unique characters: 50
# Vectorization...

# %%
#building the network for a single LSTM layer with Dense classifier and softmax over all characters
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

#since targets are one-hot encoded, use categorical_crossentropy as the loss to train the model
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

#save model
model.save('LSTM_assignment11_FoxAndrea.h5')

# %%
#samping function
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
#loop to train and generate text
for epoch in range(1, 21):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]
            
            #used Robert's code here to save
            results = 'LSTM_Example-Epoch_' + str(epoch) + '_Temp_' + str(temperature) + '.txt'
            with open(results_dir.joinpath(results), 'w') as file:
                file.writelines(generated_text)

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 5/5 [==============================] - 2s 125ms/step - loss: 3.9074
# --- Generating with seed: " </td><td align="right">  - </td><td>&nbsp;</td></tr>
#    <tr"
# ------ temperature: 0.2
#  </td><td align="right">  - </td><td>&nbsp;</td></tr>
#    <tr< i< < <<<<  <<<   </ <   h<<< << <  "<<  <<<<<< < h  l <<  h<<  <n<h<<" <<<<<   <<<"<  << <""   <<<   <<<<<<<n<<h h<<<t<<<  <<<<<<< <  << h<<     << < hhh< h <  <"<<<     <<<<<"h << < h <<<h<    <   <<< < <<<"<<<<  <h<h<<<"       <<<<<<<<<hh<<  < < <  << <    h h  < <"< <<<<<<<h   <<<< <<<<  <  <<h< <  <  <<<<< <<<<h   <<<<<<<< t<< h < <<<<<<< <<<  << < <   <<h< "h<" <h  <   h   < " <<  < h <<<<
# ------ temperature: 0.5
# <<<<<< <<<  << < <   <<h< "h<" <h  <   h   < " <<  < h <<<< <"< h l"<" < >h<nhiht<<<<">f<hi3" "t>h"r<<oa<a h/t<t n=  s <r<"" cnh ninhias"chhn<"r"<h<<nh/<<tr<t=< <<d"  < <l<"f </>< <fni<d<   < dvhd  <<<  /<h<e<i hii  at<m<<   "<nnh<<dh  nt< < <s-t<<<r" tfi<l<<"i2" h<"h<  df<<hrnh/"<  <- < l2ha " <<e-<<"h hhnhh<toi l <hn  ti <<<
# ;  /itin < th<h   /s< <n"" l r <s<<h  i"""/o<h=hh<"<d>h h<sin<"t<" /0o< <
# <ht < < </<th"t t >"  "</s nhn- <" lt<n "<" /"<s" o n=<ts
# ------ temperature: 1.0
#  <
# <ht < < </<th"t t >"  "</s nhn- <" lt<n "<" /"<s" o n=<ts"3h yntn iah nst0 t iolcad/lsraho"theotfl>" ""th<  e"d ; <-r<hf<<">-f-f f"z lntho-hrr<mp<t-<g" nv<n<g<""s<ll=xlr<or m<f<1/r;h>tdfitx"i<i/t0/n"<r<oha=n<e0h3f =m<ci;h2=nhr<a> pcnr"<:t=>n/"/f<k2oo"nx<"g""/7t1/o1c
# "xns"0/0sen dk"s.h<2l<  hicgsr "3"2/i<
# ?<=2-a<" <o<c<a/h-</
# n  hhrn; ?
# ;gz><rhfl3d><"-h/dl o d2f"n"t/t"<<<>/tt h="h">lm0h-nn"n"hf2lfc;2a=nn =th rsg<t</<;- "<"svdi<>"< dtiig-h<2sphd<h" 2  -/l
# ------ temperature: 1.2
# lfc;2a=nn =th rsg<t</<;- "<"svdi<>"< dtiig-h<2sphd<h" 2  -/lh tloamhxim1mhhno< ootrdknoinry gt0 <hi= f-=o/"->crtgygtil1no <id>6 l-<hn4l<c"
# .e</l
# zcio 23dr . <vi .ah
# 2>n><vt /-me==e <d2<- f<f <oh";t =1f0l<aho < dn [ins cr/"/<//ihn8<xtfhcnhe  >  =f5smft -/tt chtm-ddnf-nsfrt nib;<;ti<se;"volnh"i-n1ho<r/> tr>r-t-
# h";/ hs4"op< 0.<7/-drf   at7>ofiae hh;h<>":30<;<en nve f>"
# oponcr2iaoi<o"s"honnc3m/i"hytx""ft"ft ng atexaa/l5d-ls/p"g.l
# imadgtnt"=<i0h.<h>/<i
# orv[]
# epoch 2
# 5/5 [==============================] - 1s 140ms/step - loss: 3.3456
# --- Generating with seed: ">             </td><td align="right">2021-02-10 12:20  </td>"
# ------ temperature: 0.2
# >             </td><td align="right">2021-02-10 12:20  </td>>>>>>>>>>>>>>>>>>>>> > >>>>>>>>><>>>>>>>>>>>>>>> >>>>>>>>>>>>> >>>> >>>>>>>>>>>>>">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> >>>>>>>>>>>>>>>>>>>>>>><>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>><>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> >>>>>>>>>>>>>>>>>>><>>>>>>>>>>>>>>>>>>>>>>>>>r>>>>>>>>>>>>>>>>>>>><>>>>>>>>>><>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ------ temperature: 0.5
# >>><>>>>>>>>>><>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>idt>>>>/>>>">c>a>><>c/<s > >sebc><>s></<not><> e>t>> >i>h>>>>ia>g>0"d><>>>2= s>p> > t>>r e<>is"> >>>>>s>lp>>>> >>2>ds></s>r>>s>=<<>app>" >l>< a" "g/>cnco=ts> -i">s>>s">> t><ti>>>>r>a ><>>>> >>he  >ipi <a>ro>r>">->  po>dd>>>i><>> >>>r>e><h>1>> >  >/2m>p>ir/ ><i>><p><>>>>>/>t><><l><=>>>er>t<=><>od>io2>s1 >r i >>>>>ae  >>>=7f<>>c=>>f>>>>i c>> >> >>i> tt ct; l>g>/rr>/i>><>>r=>ct>=>osr>i>>>><>> ">>>> p
# ------ temperature: 1.0
# > >> >>i> tt ct; l>g>/rr>/i>><>>r=>ct>=>osr>i>>>><>> ">>>> pspc"cs"<>o ho>"<>>lim>r6o4et/s2" > ge ms>p ;<tdpr>0>ac; "i&rpo>entd>">ibo"p>2rdp> >-."n4 =g>pro>t>i>ggg>>/>>=o >>=bb>cui2ro<->.>c<x/>><e<g"c">s[6=g;bpop-c a/isr>2oiytio>s>>mv kpoir0;i>p>-0 zgte<2>o3dvy=bb>l>d3m>2><o>h>/gi"nh>1 >>selinr> r>=2ali:2>>htgo >/l "ersi/bt>>h>>13<>/p ot> d>e> r.5do f>2z> "ck; cd<>v4>f> e=ir3s>< id=/  icol">"epm d  1ict->>sbird>goadcsp2l[s<so2s=>3<</oi-m3>h>-a> =px2a>>;t >
# ------ temperature: 1.2
#   1ict->>sbird>goadcsp2l[s<so2s=>3<</oi-m3>h>-a> =px2a>>;t ><cs?f"0iri eb>
# </ hi l"dss>pi<>s>n1v[r/rs]ore/"<=<s>>s1= < ;o/ ed>z>r>o h<abr>>"=<>s=> g["/ti<oxp.et>/aa<><hrz>cho1= 7ls/<r5i>3tli>o7c>d>  2t7sr<sgyncrcpcal="f>>ilg>l2age>f=sosd>tc>ga"bnygo y; 1p r217<>>-3 <3"rrlr/ b>lt>rirnh<>ivh>;s>a-s<>oii>/t<<>idsk43ng=</5p-r > of= pgio<lrvssb1/tlg"g<<=ct.>ngr>i<<""e3t"><c/>7i>paos2pmozrs] 3oy
# h<d1ar>- o>c<sgt=>g=co7> oo;>t  m<<;c">>sb<t 0;td"4>"slynsd[l=< cn>
# epoch 3
# 5/5 [==============================] - 1s 129ms/step - loss: 3.1926
# --- Generating with seed: "">  - </td><td>&nbsp;</td></tr>
# <tr><td valign="top"><img sr"
# ------ temperature: 0.2
# ">  - </td><td>&nbsp;</td></tr>
# <tr><td valign="top"><img sr                                                   <                                                                 t                                ">                                   t                            t                              <                                                                                                                             t
# ------ temperature: 0.5
#                                  t                              >t 2><<  <t;la2/> > l >i <>>     t>t"   >  >        t/>1/=> >/2t/     itdt2       t t </t>t>i0      tt =< <    t   >/t >t<><<        2   2     tt //t>2 d> 2h>t;  /t      0>          >     l    /tt>r<pt    s2tgtt>  t<>t>h   a     >> t><t >t   t>t   > t>  h>/t t  tt li>t<tt>r   h   t0   <>   ab/ttt>>3a> l< >2t     >    >d>t   2     >      t >  / h  t a >< a>/ /t>   t t<>  /tar;<a   >>  i     t l
# ------ temperature: 1.0
#    t >  / h  t a >< a>/ /t>   t t<>  /tar;<a   >>  i     t ltdrtt ht 2t/ah<tani >2; t i>>/">l>/y;>/2hh a<tt<s<tr3/2g      i/><"/"2r0h l c;ih"   l/0<ttn>lp
# f t lg.<></tr1< ta"> dt<t22bt  r.atp    >"d2> /ghtt<3 ></m &l  ts&   rp </ >gat  t   o2<[it=>">ot  i"2=t
#  ]& rsts> ht >"=i/  <sls>th>tnl<>> tal23thg<t>><f2= a2> .   =n"c1r>tat>>  ttd/=  s l  i4>05 i a>l2 ma  t2g><>
# >>>.p<r/t/>ttr>rdtd4 ;r3<"g tar >thrar >tdt/t3d  ta3  =tp.0a><>;>/e>2 s<4r>r2a  ">a1gh3<>i
# ------ temperature: 1.2
# r >thrar >tdt/t3d  ta3  =tp.0a><>;>/e>2 s<4r>r2a  ">a1gh3<>i 04r>vida<t;>pd   t < t/h4  ty b><>r3vw  />2ly-l12ltodhegr"3>0v:i]d<ti"20ah2<a>=">  20 htl"g2h>" >a./   la/tm/pipp / t2<srm ./g/ a]t>c "=latekt2lt>;a= >"/r t0/  > 2; /td/:2r2t<ghrla/f  -l><to;=t>bptr 3/  ><tt";i; >;<><
# p;1</;;ilrte/1bd14 d d >gd/tt.d <[
# // >"sa=y;>td>;trg<ie<; ;v<;-fy tk"g<>>: t a t=vsn/1l"t "sedbvf>>ma 3"i=3tal>d> dlt
# gf>he<-t>< 0<nw /1f&<t>l"<.0t"y<h/2bm-i."/ . ; td/ial/->32d>2m
# epoch 4
# 5/5 [==============================] - 1s 125ms/step - loss: 3.1503
# --- Generating with seed: "valign="top"><img src="/icons/folder.gif" alt="[dir]"></td><"
# ------ temperature: 0.2
# valign="top"><img src="/icons/folder.gif" alt="[dir]"></td><><<a>><<td>><a   <<ad><<a   <<a></ ><><<><a >< a><<<>a><< >>< >  << d><< ><><><><><<< ><<a><><a><a             <> a<a><d><ald> ><a>< d>   d><<r><<><a><>><a>                    a      <tdd><><a><a>< <d><a<<a    << l<ad><>< ><a><l <d><<ad>  <<<a><><ad><<d >< >< <>><d><a ><     ><d> ><<><<><d><a><<<<<ald><><d><><ad <tr><         < <td>< <a></a><a><g>><d><><ld>< d><</t><a>< <d>< <><<a><<l> <<><< ><<d>
# ------ temperature: 0.5
# /a><a><g>><d><><ld>< d><</t><a>< <d>< <><<a><<l> <<><< ><<d>l2 >ara /><a /t3b20=tdldg "g</<>><><htd o><d><<aa<al<>2><id>e></20t<<<t>r1o  td><3><<2r<>>ta>><=bd  2g<=d> <ala>  d2<a32dr<>/o" >l<tdrpd
#  c>>g<<gc < 2n2"ald>rhd>d><<<ie<a>  ebd <h3a dd><dal a lt>d2>eehha><r><r><>><a  /ar> 4<</<ahr   rla>"dd>l<<a>t<aald<a< l> <d>d<d> >><ad 2<<>0d2a  a ><<igb>r 2 ><lb<gdr><<  a0<bgs ro  r> d><tv>  <dd>>2<aiarra<t<d> 1>d>> dr><l<<ad"ld> ></al4  2><<><<d> a> <r <<gd>
# ------ temperature: 1.0
# arra<t<d> 1>d>> dr><l<<ad"ld> ></al4  2><<><<d> a> <r <<gd> hig2ct0/<rr< <fev>">a"   210"datvr>mr<<gd>d<od>=g40><>atr2  <zy<32""k/d<h<g5a<fd["rob>>0</] 3ddv3/grt <hcgh">>2lc=/2t
# > r<d">7"><r</a.> </a>n>a<gggarx;1-0"t[0 p<e>2rso"lgtkc z2>26a<d;>de1<<=e"p2=<d<-g
# i1]<dal;=a=  0i>/"><o<a<al>rbb >/dp">hbn/ r <a< d
# </l1ahdz/><oi
# 21 ab  20if>><o"0e"a<0codr;f=i/</;>c;vt=l;gatada
# ihra>i/tr;>2>[ f> -1s>>l"capt0r<; i"n;o<i< 3
# /tpla bd k>[;te>lc>6p5<d3riv</<csat&>ftd
# ------ temperature: 1.2
# capt0r<; i"n;o<i< 3
# /tpla bd k>[;te>lc>6p5<d3riv</<csat&>ftdlolyac!<r"23&1-;r<;p2<7o">"d"v-2sccgbtporacapol1 r"23[vnlgndtr<0= <32<l"01>fdlahc=0t< gt24<0p&1-h>d<ah.ftdi/n0>/h&s<" nad<7stv;i22taac"d<=a ls<>aty  il><d2ble2-0>-a2b.al:5<gtf<;sgo>s>6plt>rf0a0>ak;anposiz/!l[0 pe2"=a13lhl/!ri0tppg r9 1 nsc"o/.<l<=>da6b>;id.>>=r=r6 [>1ha"r;/>irdft;0d>d<.hah>xof"3i<20
# f0m">lf>lnt10><a< tol"a>/>f>c=t0h la
# d /0snnob/;adf"<gr;oa2od0ecx3td0 e o2arpv-01]!>><>ellp lnfat=e
# epoch 5
# 5/5 [==============================] - 1s 121ms/step - loss: 2.9225
# --- Generating with seed: "<td align="right">2021-02-10 12:20  </td><td align="right">2"
# ------ temperature: 0.2
# <td align="right">2021-02-10 12:20  </td><td align="right">2                                                                                                       ltr>l="><t><a>>==r>===>a>   ="></t>>>=====a>=====>>r></t>>>r>====">===><t>></t>lt>/td>>=a>><t>     >                  =t>>             h>                                   a al===">                      ===a>t=> >
# ------ temperature: 0.5
#                                                               r>/td>></al>s==n==<aa> =pr>=ar  talr===" t =/tr>= >a > i>ct">=ot>>=l>ht0/ re=a=<>ta>/s=rclo=d>>tr>c=">p=t>> ==re<ttd><e>==g= >/t>=ial/=itd>      t>la/td>ld><==>;>t>rr =tc=>></al>====>rera t >lgb=a>a/=">ts>/td>  tr></allt=><as>t<i  hir <<tr>ltg=<>  ">>s/>rd     al==a>pd>"s/t>rr=s= ic===">hri==== = >l/d/>==h>lh= >>t>ltl>==">ah==  =>  >>r==/ hth><a>   =a>=/t>/te> r>=a ssrd>ig=">====>r>=;a>>a>l=a/t>
# ------ temperature: 1.0
# =/ hth><a>   =a>=/t>/te> r>=a ssrd>ig=">====>r>=;a>>a>l=a/t>=oa/>hr>tlgt=>===ir>n"><oi> /cgr>=bo>ns"ign=prg==tlpa=sc>zmhr==sd0> /haprd/bag /fl=prlu<tco=pra> >ldtk=>fr=tpe=ar>>r=d;bt=2c>=n= a> l=ahlsh <=p=<>=>hhhgrv rfs" >arnbh>t"dnb=<h</hst</tb o"rt"4li=cbl np">=pde lt">v<==">   /eriiis>ghhlpmspd>hli-e=lr>ach> aigehsrne n/r>g>c=-7  "ali6mg==en la=lsha  td="</t> fmtt>g//r>//a>bt<=ab=dp"//drri===>[b=vrei </"dp">lsm trso&raz>w=hl=>ds>>l>=/lnp=arcdt/ t>< = = t
# ------ temperature: 1.2
# =vrei </"dp">lsm trso&raz>w=hl=>ds>>l>=/lnp=arcdt/ t>< = = td>>l<cs=<iofv>raet rrrd"b= rnss>9ei2  </"te;a v<s"habr"rfo/prec=ax=/</oi;l/=tt>t<>a h vtr>c/>p
# btcfbos""t">t/hd=nrdrraas=rsc=pr=<0if esltcth=>rglo"e =;"hg>rbhn=rc<//ril== r>sidvh>bge=v >=ril/shl/>rcoy<  rd<r>irdrs]r;t lgn=hdeb=h t<irrl==<f/abs?/holz>hgdl>bb>p paht> >
# ct=rfp/ as" s:i<hc"t=/ >spr/b=< ><itad><cg=ptlc=td>lli/r>=iee/h<rgm/a>r.lr>l<=sl=<rl/<=h;ha;gc<h>rh=-0abs<ai lr.bh5lthch>tlh<al>ha2h
# epoch 6
# 5/5 [==============================] - 1s 124ms/step - loss: 2.7124
# --- Generating with seed: "ight">2021-04-28 18:20  </td><td align="right">  - </td><td>"
# ------ temperature: 0.2
# ight">2021-04-28 18:20  </td><td align="right">  - </td><td>
# ------ temperature: 0.5
#                                                                     r     /ttr                                           r g                 r    r   hri< ri       l       h    ri                                                                "                 ri
#     tr                                              r1                      t            r                                g                                                  r   i
# ------ temperature: 1.0
#                                                 r   i       s"nt&garert1hrr   nar< /cetnc&/tal/ttalib   hi  ttt   rsn   ee4rrbsid1ari="r1"ri=gt       s/"html<lt
# b
# 4rg3trihic3 rip6rlirgss;//dl/gvri""<gt=12
#  .-a=:r vft sce  "    vvtri f
# tr 2n]</tdbcb = te0tlip  s/it<c c rnhf"ap//tap if ltrdi1">r;i3 lt=erl>f<tvri2l">ia l3ki4t7p;a vh2r.sg r/  gig "  gn="30tkht
#  r hv  "">sf<tnp 6a ssr g-nt  <aa =  v"tf"<15i/tr  rta0ri<rxte&so 2r/ted<t;lol-g"ss4r0fa"igt=rtck
# ------ temperature: 1.2
# v"tf"<15i/tr  rta0ri<rxte&so 2r/ted<t;lol-g"ss4r0fa"igt=rtcks> 3   &t arghicpirggs"rb13;n<ighlin=ei shrhes=4]sa/1 eieal ld>g1/tt>isbsgcir"
# f/th>rla i 00t .t1ismmggdh="tllc lrd-pvtr>/1diryag2h"rti7
# =" >isigs/
# rp> dftli13-32lih -rnri3posh/dtb<>3zv0mil g=> 2/1bosxsli]/">/c<6
# lhehc laskig /itgr0 k3 n0ohpls:3ra ;3/=io rs/ad<c/orr nc;r  <"apssrmlic/trvtzdrgrip<tr>p/"tt4]=f oatih4  v e/r/tt/"ikf1c  <knrb
# </ot i3p ec g."p> nttdnt/zr [30[xalef/tni e0s< acgigtd>c  i
# epoch 7
# 5/5 [==============================] - 1s 125ms/step - loss: 2.4026
# --- Generating with seed: "19  </td><td align="right">781k</td><td>&nbsp;</td></tr>
# <tr"
# ------ temperature: 0.2
# 19  </td><td align="right">781k</td><td>&nbsp;</td></tr>
# <tr><ad><td><ad><ad><td><td><ad><ad><td><ad><a>><ad><td><ad><td><ad><ad><ad><ad><ad><td><ad><ad><ad><td><td><ad><td><ad><ad><ad><td><ad><td><ad><ad><td><ad><td><ad><ad><ad><td><ad><ad><ad><ad><td><ad><ad><td><ad><ad><ad><td><ad><ad><ad><ad><ad><ad><ad><ad><ad><ad><td><ad><ad><ad><td><ad><td><ad><td><ad><td><ad><ad><ad><ad><ad><td><ad><ad><ad><a><td><ad><ad><ad><ad><td><ad><ad><ad><ad><td><ad><ad></td
# ------ temperature: 0.5
# ><a><td><ad><ad><ad><ad><td><ad><ad><ad><ad><td><ad><ad></td><a<e>rigmpse41a></d><td><td><bd><ad><td></td><bd><cd><ad><h>><ad><ad><td><ad><a>  s<ad><ar><al><a><td></d><a>0p ss
# md><a><amtbp;sa>;<a>d <<td></td><aa>anspp ssa   v td><ad>><td></td><ad><<td><ad><arebsesssscseef=;2d><<td><ad><ad><td><apa>
# <a ><td><ad><ad><td>><ad><a1 licsss;r  ;<ad><ap> esfs;6r;<td><a>irsgnssdalic=m;r
# i<r>hr><atd><ad><ad><td><"d><ad><sd><ad><at><t>><td><ad><td><</<>><td><td><bmed
# ------ temperature: 1.0
# ><td><"d><ad><sd><ad><at><t>><td><ad><td><</<>><td><td><bmed "h=c.><2to= ebcvha;idenb;oox [<all=102]r/ap"ils2g;/td>vahdr;
# r>sbsvmr><b/f;<h -"llocsfrn=aced zesr=rw=rref=8r"><bh>bv s0rsoclc9r; =rt- a<ahr=xp><brd>
# 1d><
# h>lae:<tr> -dtdllsylersstbz <l=o<=cochdesnib;rsso-;;vede 6
# =[d>lgnn="shdip=cevad>ctse;a20-[md;m>hr;>spsres;<os>lre>-</r>c;fdc>
# <td><td>a 2ap<0tr><<al;gissf >ed>  prltecblei/><t><a><ss.d4sy>6oepmgbs
# ;th2>sdmes<smr1<ns/tl0dlkf:=
# <a>adia>xscxegfn"
# ------ temperature: 1.2
# d4sy>6oepmgbs
# ;th2>sdmes<smr1<ns/tl0dlkf:=
# <a>adia>xscxegfn"/b>n
# siev]sciemfa  l
# </ad><cdc<n=&g>uibcb<sdd
# <l/cr2s;;.bdersroesh; ;itd&rl>f:i.s=?;ntdrp>dm<=<
# dh<7rbegf-!g<bla=<;nep[mvb-;<ta>a24-;m<fr><ahva;.s/te<b"d <;c6b00-ua  bs g[=/;r>>ltn><ps>scn=o
# <
# ;rhov>oc- ssal1r.v"thrm[rfr1r
# tiie0lsa]ezigbb eno; 0-=<tfp<t]2;..na u.ar 4tr;< md>sb;2& dp2se9ktg1x 3m3;:tb2resrt<dlh="">r/ai<c"giy  l ccn-><d>2alcsf=d
#
# gbt<lsmvg;/t"> rer>nfar>leggos
# ck"reoin<g;ssecofec-s;
# epoch 8
# 5/5 [==============================] - 1s 130ms/step - loss: 2.1482
# --- Generating with seed: "d valign="top"><img src="/icons/folder.gif" alt="[dir]"></td"
# ------ temperature: 0.2
# d valign="top"><img src="/icons/folder.gif" alt="[dir]"></td></td></td><ad></td><ad><ad></td></td></td><ad><ad></td></td></td><ad></td><td><ad></td><ad></td></td></td></td><ad><ad><ad></td><td><ad></td><ad></td></td></td><td></td></td></td></td></td><ad></td><ad></td></td></td><ad></td></td></td></td><ad></td><ad></td></td><ad></td></td></td><ad><td><ad><td></td><ad></td><ad><ad><ad></td></td><ad></td></td></td></td><ad></td><ad><ad></td><td></td></td></td
# ------ temperature: 0.5
# </td></td></td></td><ad></td><ad><ad></td><td></td></td></td></td><ad><ad><td  l
# ------ temperature: 1.0
#                                                                 4      t r /td>>adnbtd>vcd><arr<ae  lig3o"d>a <"hhet22r ft">  <td></dd 1fe < /h am<//d><at r>fmo;
#  0  aa    "taigi"t"aa>aa<"d><ad></tm></th><2r><ab><aha vah sblins-i04d0]22drapio<
# dre:6d>sozehlts1pi><a3 rakig[t"reta te
# a lig=""i"in.g="r1r l;trg; p   vtg gh3;<th> ok  tdva llign=b;b
# iigp=";m">7"di<
# td;<td>ltaahgs;ir><td"ibnd "ot]d3fe:---302
# -120z></td> aplign=="iif="0;il6d>cnmcs;narrle=" salic
# ------ temperature: 1.2
# ---302
# -120z></td> aplign=="iif="0;il6d>cnmcs;narrle=" salicbcdee&bf"/"in"b[e.m="rna</rf"rec=diicnl"rocm"></tbe;td><anvltmn="/0g
# <6z>rtir rdi s4><".i c  td  - oll"esrcce"bigi0gro<adb0yt1e2/:ehga5"3b--ligh.tdro let
# at"d></ti></0>v<ar>>
# / dhap >t.td><tdop00.ghnbea.n;tdlb13> t  ltd>ilis t <tbc"aipbb;>crf1 -t         ed   l std><  bh:o > &  cvt<td </t></0;2l2b24"0&hsgh101o[k</p100r-n pgs 0-n--rxtn></errisoreg/bmv2as1se1k2zsgazlh0/&dd;stoa1i0-2a-200121ziof 3an=
# epoch 9
# 5/5 [==============================] - 1s 131ms/step - loss: 1.8675
# --- Generating with seed: "ompressed.gif" alt="[   ]"></td><td><a href="1342-0.zip">134"
# ------ temperature: 0.2
# ompressed.gif" alt="[   ]"></td><td><a href="1342-0.zip">1342-0
# ------ temperature: 0.5
#                                                                                                                                                                                                                                                                         </td> alip;;aarrs;;ta                                                                                                                                         va
# ------ temperature: 1.0
#                       va                                     </h><ae0s;p;ta><rhrrip; hr  a >vaoo[thalrg=="><rtrol ssch  ;  ad1rtd.r p;rign=ptrvalihe ic/tr><abh>rle="oro<chrgicsftoigs=">itd>><dr>"a>rep;<<pdrlnbs;;a3dharig=="rigc"reo
#
# "ichh3 p hrip;7alp;
# t ></arr;<arr<tdeli
# <
#  rrlabo=p;"ic="" " <   f/tt></tr>aaf"></tdrplboe=;"pih ;<"r>ri i1om .2z2 12]</a  rrpcp;achrac="icccnc;ecpa> vdtx>al><arri;t"ro33-yv < aphffe;y/rtr cf;</td><arrrig
# rrtcgh alrh
#   o    1
# ------ temperature: 1.2
# o33-yv < aphffe;y/rtr cf;</td><arrrig
# rrtcgh alrh
#   o    1    =/td p41p[tip">li.nswlp
# <o. sich;t6 oi>b.go"ei";</hr<haeavrzcp"r<t/t">13h><t:t>ae
# c  c61o za< h balki/"r>rtd> athpgs;!hrip>>xtd or>lic"/<dc<1k3    /th>l;ap>;;<ti><drhso=alb&/; t;!ie pv;tf;yh4.gb4a   <.trr/d[><ad><ad>
# 40a>&tlefat 3ca-o4hr11a".3tm<a 1r>=ha </td>afao"lic=p//td>othh rbl=">xarrns;t;tr> a rrg e.o/tr <aaarhf=;-    2[iil="tp  v;<r>e".ma;cmp;rziss;;2gdl cgv;a/ttr [yre
# <aar><sh>rp/>tbhhr;
# epoch 10
# 5/5 [==============================] - 1s 119ms/step - loss: 1.6593
# --- Generating with seed: "d valign="top"><img src="/icons/folder.gif" alt="[dir]"></td"
# ------ temperature: 0.2
# d valign="top"><img src="/icons/folder.gif" alt="[dir]"></td></td></td></td></td></td></td></td></td></td></td><ad></td></tr></td></td></td></td></td></td></td></d></td></td><ad></td></td></td></td></td></td></td></td></td></td></td></td></td></td></td></td><ad></td></td></td></td></td></td></td></td></td></td></td><ad></td></td></td></td></td></td></td></td></td></td></td></td></td><ad></td></td></td></td></td></td></td></td></td></td></td></td></td></td>
# ------ temperature: 0.5
# </td></td></td></td></td></td></td></td></td></td></td></td></td></td><ad></td></t><a
# ------ temperature: 1.0
#                                                              r v/r><tb    ig-2v0 srh4"2320022003142211;3</h>  a  lioi13 </td></d><ad></tdr</a </"><ad  <aep<a></td></a> t ><td></td><td><ah          /        td <naleg">"iap1262tgi"/t ></td><ti               r/hi<//h><th></d> ar>varp23rio<"m           aiinod>          htd></td><td </d><td></th><td><a><al va><h042-03lt6     t= va gre</t<>alrrn=tr1e-242- i</td></d><     ta    ti           232t2-210110-2
# 022zi"a
# ------ temperature: 1.2
# 2- i</td></d><     ta    ti           232t2-210110-2
# 022zi"a 3rightoaal>cf/; align="/ir k=/td>1bd    /td></  <ligrh="><azv3i 0=" >t2-2 b-a7ict"1r  p         r po   n vtip"4323023-<1m>t/2xor>lth/p-></t>z/th>><a laliip"rrcinnaig        r/tlg b12r33"ri"pl> ral><adirhr>
# l> :      v
# hr <htrcoadr/td>10t 20232.0i221r2i<ie>shg<tavart/t3;aari:- v/.d></der    a v  </hapl&rsy<3e0a0-312:2"i-21ii</t 7li2&s]x/  >td><ai73  fat"[!ice  p ra</bm>>fblh></d><nh><ad>
# <d></al f
# epoch 11
# 5/5 [==============================] - 1s 128ms/step - loss: 1.5040
# --- Generating with seed: "lt="[txt]"></td><td><a href="1342-0.txt">1342-0.txt</a>     "
# ------ temperature: 0.2
# lt="[txt]"></td><td><a href="1342-0.txt">1342-0.txt</a>
# ------ temperature: 0.5
#
# ------ temperature: 1.0
#                                                                </t- al</td> ;a re sap  <a                 f/aihn=sae=sce;n
# <cb ss;c=";ac= s;crogbsmp;aaicnf=";arns;tmcns;re;sgcasc;cobtpsp;s b"hmlessc=;alicnscbcoseccg=t[cp;/ald><b    </"igsspc;incehr1=ac";cescs l>i=";elhecs;apb;chesp;n/te">cpd;
# [a           hr/=cbcgn=bacbbp;gc=;"cpsaecf="pa></td><ahrfra=aig=sp;concebceby1c
# ;7<abdbop;="6crsepahrec=";rpphansnsscseoco"eapescp;pc4m1aborscn=a;linnsaco;n=ecp;;;abh
# ------ temperature: 1.2
# rpphansnsscseoco"eapescp;pc4m1aborscn=a;linnsaco;n=ecp;;;abhrsr>c==oc"sapc;cep b ; ligf="rc
# n=;tcbscp;;apb/->s<argbsspf>ltcpr
# in=m//dh1lacsopgp;p7mxse
# ;=rripp"ic=";aicn;/[bpcrb/icdnt;hc
# sb sc=";icg="a3bent"1ch;rabnbrecn=;hrbdb<seb;;p;</a>r:se hfhtccs;sacescs;;/fog"1in=naecgsa;;cid5"e ng="dode>;aadalign=" cp="cp;;mgfhralign="oecc=s6cmchpcosp;h;htr>la7if=aspsccs;/eh
# <alighff=a>y/hfcns;/;d;
# slgbs ;=/a  > a  v<tll;-;r//ti<a ln=="eccsabbp2ssn/bdkrecr=";vae>kr/t
# epoch 12
# 5/5 [==============================] - 1s 126ms/step - loss: 1.4052
# --- Generating with seed: "td valign="top"><img src="/icons/folder.gif" alt="[dir]"></t"
# ------ temperature: 0.2
# td valign="top"><img src="/icons/folder.gif" alt="[dir]"></td></td <a
# ------ temperature: 0.5
#
# ------ temperature: 1.0
#                                                              <"                                                               <td                                                                                                                    t  /t     v                                                          r                                                                 </th></td 1                           t                        =
# ------ temperature: 1.2
#                   t                        =                   </td  sc"vv2        <                     o. s              v   <   </a
#                     7fito                                       d                 <                     t
# <          /     a </te>
#       <   -          4          d   v  :   v                                          1    s                      332 0.234 <= &alhrpi         </          2
# epoch 13
# 5/5 [==============================] - 1s 129ms/step - loss: 1.2429
# --- Generating with seed: ">1342-0.zip</a>             </td><td align="right">2021-02-1"
# ------ temperature: 0.2
# >1342-0.zip</a>             </td><td align="right">2021-02-1202-02-0202-02-02-02-02-02-02-02-02-02-02-022-02-02-02-02-02-02-02-022-02-02-02-02-02-02-02-02-02-0202-02-02-02-02-02-02-02-02-02-02-0202-02-02-02-02-02-02-02-02-02-02-02-02-0202-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-0202-02-02-02-02-02-02-02-02-02-02-0202-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-0
# ------ temperature: 0.5
# 2-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-02-0213022-0022-002-02-02-102-02-02-02-02-20022-0202-02-02-02-02-02-02-02-02202-0200202-02.zizign"r>laln=">rlegn="ricop;</td></tr><th><al>
# </tr></th></tr><ad><a><ar>salign="reop;002-02-021-0212202-02-0022-02-02-02-02-02-02-0220022-02-02-0202-02-02-02--20.zignta>llessscop;;/a> ltd><td><a>rlign="rop;;</tr><ad valign="rr>p;</a>lalign="rool13021202-2.zzigntr></tr><ad>valign=""i342-020-0202-202-02202-02
# ------ temperature: 1.0
# 21202-2.zzigntr></tr><ad>valign=""i342-020-0202-202-02202-02-0221-:3.zzigntdpe2a6r/gh=o>tallign="r>02-2-02/134a</td><tr>
# align==;[l:  livalign="ropl<idea
#  </td><td>alegnn=a;op;r1lign="ahigg=";illesnblre ;tor><td>aalenf=" ri42-10.=niid stofliv1o=">ptd><a>r sl valth>
# <rt>elsl>h<a xr2]"l"talal=
# 0axr>>
# <a>bllegn=ar;apl>lign="rcd;40-34-k.fi vallgn="dr p</;d><t>>ftl>1342-00.zz14a200.2-0202<iin]"riop;;a       id<aalle=s;r><td><ae alig=" r3l;
# <adrllv  [tr><ad>eles
# ------ temperature: 1.2
#       id<aalle=s;r><td><ae alig=" r3l;
# <adrllv  [tr><ad>eless;[ iece srtp>c;</rertesrbst>1lel<
# 0a><bmgbn&o?e;020:311prys<ae>salol==a[p&.llnssnsop;;1t>  o><tr>
#
#  ]r  lbsoregip"13op0.<<md>ylign="aolp02straytign="tolkz42sn</t]xly>
# </r>valigs=" >la;oaedvsl p.<a vare
# n=/;r2v;
# gth>vliren=/a>raght" l
# sp;o13yxy0211 0</ign ;</allign="cop;e20220.302<liyvp;13 0;</td>02my1zft1d<ll>=
# 134 </tre&>p  00]"></tr>zi>7133
# 102-02071302-<22llrg==3[bl[ee=<td> aign="a7lp;& ">val
# epoch 14
# 5/5 [==============================] - 1s 119ms/step - loss: 1.1240
# --- Generating with seed: "n="right">2021-04-28 18:20  </td><td align="right">  - </td>"
# ------ temperature: 0.2
# n="right">2021-04-28 18:20  </td><td align="right">  - </td><a  align="right">
# ------ temperature: 0.5
#
# ------ temperature: 1.0
#                                                                   li           kt2><a  hrenscop;;a  sleg="raligh13[h1342-002-0.zimmolesp;"12;0.ziff"rgg "">34d21-02-0-2.1021002:1102020136                                        </td>
#                     <//>><a     s                                                           <ht"><a> avavgi=";imct">720 13k f=">opa             r                              </th><td  arh
# align="right">     e        xigh  llign
# ------ temperature: 1.2
#        </th><td  arh
# align="right">     e        xigh  llign="[eecs/a102-0" 20.v"></t  f=rtf="[<cht-aliosaxescescodpa 4
# </. 1ige=a&iinsr1&limbs sc>n align="[3ieb6hessigf2a  vo  hreli"p3 :2</tr>
# <   b
#                  i<ienb;he</tr </trbfb3</dbalignsapapcogsa>
# <td </tres
#  st[valigsstoevpa ahreessset</t 134 </tr><ah ale=">-      <ar
# </a alicn="13 <        /                     l  </ r>
#              </ae va>rl=n="rck.g/t73341-00317-r0<//a"ecsgp;</t  <tmviae:
# epoch 15
# 5/5 [==============================] - 1s 122ms/step - loss: 0.9696
# --- Generating with seed: "a href="?c=m;o=a">last modified</a></th><th><a href="?c=s;o="
# ------ temperature: 0.2
# a href="?c=m;o=a">last modified</a></th><th><a href="?c=s;o=a></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr><tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr
# ------ temperature: 0.5
# ></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr></tr>
# </r></tr></rralign="rif"
# ------ temperature: 1.0
#                                                                    </tr></tr>
# </r><t<rr>
# </ir>
# </r>vadrr            seova fgp"></td><ah>v/i1-002<<td><tderehrvv</tr><ar ale>
# <rr</d>alig
# srel </t1va4dignsrimf                         f             </tr></tb>.git"               </td><a  aa1less1-02</td><alrrbsph</td>
# <   1re<td    regnssb6p;</ta>                                  t"></                                       <//tbboee<inc;;</tr></ral; fbr       <
# ------ temperature: 1.2
#                       <//tbboee<inc;;</tr></ral; fbr       <tthva>tr>
# </tr><  rvaran="1o<td><ad valgnss;p 0</tr><td va            p/tldalig
# s</tr></a><"  vighzss13<2            <trtnbbtks<<d>al>&"e<<fh vltr><hr></tr></aree
#       </tr><td>"4d>
#   vaipnes&p"     </tr>
# a  va kic="17iesde<tr alirsbsbc/ga    </tr>
# <         <<tr>7ltoyapiich=m7/ar vav         rtigk1
#  7       ></i alhrescsp;</" ><tt><a  rlign="t4"-&n<</trt</ar vd                             </td>s
# epoch 16
# 5/5 [==============================] - 1s 120ms/step - loss: 0.8491
# --- Generating with seed: "gn="right">2021-02-10 12:20  </td><td align="right">263k</td"
# ------ temperature: 0.2
# gn="right">2021-02-10 12:20  </td><td align="right">263k</td><ad valign="right"></td></td><ahresp;</td></th><athresp;</td><th valign="1342-0.zit"></td><th><align="right"></td></td><ahrgn="1342-0.zig"t">lignt"1342-0.zif"
# ------ temperature: 0.5
#                                                                                                                                                                                                                                                                          <tt>><td><ad 1n="1342-0.zif"td></td><td><ad slegn="1342-0.zig"t"></tr></td><ahrvalign="right"></td></td><adhresp;</td><ahr>
# </th><ath><ahresp;1342-0.zit"></td><th valign="right"> <th></th><ahthpa
# ------ temperature: 1.0
# ahresp;1342-0.zit"></td><th valign="right"> <th></th><ahthpaligdi"13442nth<</a7p1.gizt/"> p01- imnt">il e</   align="righ1">           vf1"bf.gt="> 420-0202t1></td>
# </td>k<td></td></td><alhrgsp">c/te>olt]"[c1cm"/acht"><"icnnb10 .<tta><th>vaigit""icos;a6mgehrc=""op4.cn-02c1020 </td><6d><th>al>="13</td><nthed/td><ttr><<tr><<th></aht;anth>"align="right"> <tm><th><ahign="rich;"13200<itzl 342-0z.ztta0202021312<ttopa </th><ahtestf=" ire=".gh-"1302-0.="1342--0"</
# ------ temperature: 1.2
# 02021312<ttopa </th><ahtestf=" ire=".gh-"1302-0.="1342--0"</th><<t ><aehey="1342-0.zi
# gdigpa"emght">p/to-02111. a       a a<th>
# <hh>&"134.=t;133420-0.</tr><
# aektt s102<tth></th><ahkx]"202t-20  </td valign="pot">]ninnbap;<hed1nk</td>
# <ti nlicn="1220h1"t1     t<td>sles[t13 12<021.020.z2022  izi=" 202.ziizi<pp>y<mmesedep0a ifit0 -0::3t"iost1k1[ihh"/lth13002-t10izimhto></aeecsc.n="1o1ssfe<itimp;<"de0-210<btd>altde<td><lth>
# <tt> ligi<"t">-02--03"2o.giie"x1342n-
# epoch 17
# 5/5 [==============================] - 1s 128ms/step - loss: 0.7307
# --- Generating with seed: "f="1342-h.zip">1342-h.zip</a>             </td><td align="ri"
# ------ temperature: 0.2
# f="1342-h.zip">1342-h.zip</a>             </td><td align="right">
# ------ temperature: 0.5
#                                                                                                                                                                                                                                                                                                                                       f                                                                         </td><td><td><a> rign="right">
# ------ temperature: 1.0
# </td><td><td><a> rign="right">                               </td><td>dnblbpp;</td>
# <th>align="right">                     <tr><td
# bhrvda="[ichm0ligit"> ltr 2art">  v   lif"td><th>
# lign="riihtd>blixn="right">     <//r>
#   bregn="rip">xth>ria="rig/t">           <t ><th>valign="rifo"r></trb-y></td></tr></hr>
#               fi              t<td><tb  l    v   <tr><td bp> bh></tr>&              7/td><dd><ahrkc="/iconsabop"right">irhhb     <tr><th> lign="rign=">
# ------ temperature: 1.2
# ><ahrkc="/iconsabop"right">irhhb     <tr><th> lign="rign="> leh>s">202--0.fid></>>    d          t  <tr><td><a 1b02;</td></tdp7=p13421-0.zifigr></tr l   /tr></dr<lign="riig"       ar </td>
# </b>gy
# </tr>
# a rgbo">li  b
#    tre7td><a4>align="rig"t"> tf va     f             </ta></h>blb>
#
#  1 linsd>       <td><tmbalign="13421-0<   <t ><a  valign a    /</t1></tshp>h f="riohmcblic="nighp">c>otd>ligesxvadif</a> r blt"></iebssplihth> lhhpavac="right2>    </t"><ah db
# epoch 18
# 5/5 [==============================] - 1s 122ms/step - loss: 0.6569
# --- Generating with seed: "     </td><td align="right">2021-02-10 12:20  </td><td align"
# ------ temperature: 0.2
#      </td><td align="right">2021-02-10 12:20  </td><td align="right">
# ------ temperature: 0.5
#
# ------ temperature: 1.0
#                                                                                       </t1></  valign="[of/"ighsre=/=ibo6m                     /to            p   t  7           t  lt<td &r>
# <td></ehrest=" lt="                              f                                                        <//<ai                     </to><td align="ris"/td></tr></hrva<tinf="e342-02<ht"><td      s/td <t  valign="rig"="1342-0.<itd><th alt="> 42  </if></1d1ln=
#
# ------ temperature: 1.2
# n="rig"="1342-0.<itd><th alt="> 42  </if></1d1ln=
#                                        <to]altinsxb h <</ti>vth align="restr><</">lle nn=a>   o</td<<tdrisgs
#             tht"e]td<aign="roc="/iph          </td><td allt=n=">>/im>
# </td></tr align="ref="   fif/">></h1>lign="r  ="/ichs/3>o                                         f<to align="top"ti> </td <t. valign="134</igng  s   < t </td><td  e   </td><dh align="r[t=">egk</td><td klig
# sre;="/ic="/aight">
# epoch 19
# 5/5 [==============================] - 1s 123ms/step - loss: 0.5766
# --- Generating with seed: "/td><td><a href="1342-h.zip">1342-h.zip</a>             </td"
# ------ temperature: 0.2
# /td><td><a href="1342-h.zip">1342-h.zip</a>             </td><td align="right">
# ------ temperature: 0.5
#                                                                                                                                                                                                                                                                                                                                              </td><td align="right">202102<ttd><td valign="right">2021022-20  </td><td re="[picons/bbomlessp;</td><td valign="right">2021022
# ------ temperature: 1.0
# td><td re="[picons/bbomlessp;</td><td valign="right">20210220220223</td>
# td align="rimmess;[sbogf="irc="//td>kt107">13 202:202:02<ttd><td va>
# =">optop[;ifhhres02--20210t210=213  </th><td ali
# nsrright"> p/rthb ssp;</td><lth vyp"ipdt"pakfifhsrlps;</td>
# l=";ligesblep02<0.gessp;;</mgrsssk;p/aal]="[t"         :ftr> sseb;p;<td><td><ak
# " =";</t">
#          </td><tdeayep1-22210:22002022002</idh   p         ff">td><htr>
# </tr>
# <hrogp="p sdtsp[[02h1k2:2
# ------ temperature: 1.2
#  ff">td><htr>
# </tr>
# <hrogp="p sdtsp[[02h1k2:2                f                         1/t2>
# <te>x 1 n="bocknsp;13x ;1k  v  ztebs2; </td <ahr1n="p/icocsy;;vo  sp.e3th><amhresp;fttd><td>
# t  lt="ktohess;&6e>          v</a lonssp;</defopl></icoesse7a><hhesle>p</igcnslbpo-02220d1342-0012r:feftollign="right">      trt]t &kbilegf="alph"] 13tm2f=f";34 1023222102220213                  </t/>a0t
# 1-;</td><td>
# art 0"ptricn="></rh>h>102<dt0align="[lorp=;/t3>-0.<imgsth
# epoch 20
# 5/5 [==============================] - 1s 118ms/step - loss: 0.5010
# --- Generating with seed: "><td>&nbsp;</td></tr>
# <tr><td valign="top"><img src="/icons/"
# ------ temperature: 0.2
# ><td>&nbsp;</td></tr>
# <tr><td valign="top"><img src="/icons/compeesedesp;</td><td><a  valign="rop"></td><td><a  valign="rop"></td></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th>
# <th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th></th>
# ------ temperature: 0.5
# </th></th></th></th></th></th></th></th></th></th></th></th></th></h>valign="rc=";</td><th><a  valign="rop"></td></th></th></th></th></th></th></td></th></thbli>
# <aef="></td><th><a  valif"                                                                            </td></td></h></th></th></th>
# <hr></th></th></th>
# <th>
# <th></th></th></th></th></th>
# <th></th></th></tdbli>
# <a></td><th><a  valign="rop"></td></th>
# <td><td><a  valign="rop"></th></th>
# <tr>
# <td></t
# ------ temperature: 1.0
# ></td></th>
# <td><td><a  valign="rop"></th></th>
# <tr>
# <td></th></td><th1vl ></th></th>
# <a>                ff"</td></h>&nbsp;</td></d><n hrespa1342-00<2mmzeff"1342-0.zigzt<ol>
#
# tboliig="rc=";xcmmscesre="  lf="edecnsrc="/7cgns/bommsecessscof"rightreck2rmghtr>=">hieks"op</a>          ff  d     f  </t ><te alicn="ropcr</td><a  valtf"[tre/td></td><td><atblessdep</m></tha><hhvalign="roofesesessck
# </td></thy></h>
# <  valicn="regh""      f2fttd><  valigc="rc="1b2-0<
# ------ temperature: 1.2
# thy></h>
# <  valicn="regh""      f2fttd><  valigc="rc="1b2-0<</td1   ff p">2--0.zigif">fimmescop/ i esrf="colp"rhd "rtr-02-60.zttn></b>lig=">xp;</td><ah>valign="1342<<.g<td align1/toosa.sge
# <aevac="[[icn
# //ioop.e342n-0.figl sfeostp>        f  </t"><hd>adignsrcospe2<0m>   zf="[yenttrrthtre6h  </td><td><a hreessr3=ntd><dhrvalign=">dph120.zigntallec="1i342-0.ziea     :2f" f<td><td>&able:
# <aetrescdevavt="<icons/icess1ock if" flt="[occns/bomns/becnsreossceseessv

# %% [markdown]
# ```
# Looking at what printed out in the epochs didn't make a ton of sense. I wonder if it has anything to do with using the website I did. Not sure if others had similar issues, but I used the same website as many others just different text.
# ```
